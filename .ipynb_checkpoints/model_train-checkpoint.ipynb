# %% [markdown]
# # Drug dataset - Sentiment Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
reviews = pd.read_csv("reviews_matrix.csv.gz")

# %% [markdown]
# # Modeling (FULL SAMPLE)

# %% [markdown]
# ### Cross-validation?

# %% [markdown]
# from sklearn.model_selection import StratifiedKFold
#
# cv = StratifiedKFold(n_splits=5, random_state=123, shuffle=True)
# results = pd.DataFrame(columns=['training_score', 'test_score'])
# fprs, tprs, scores = [], [], []

# %% [markdown]
# for (train, test), i in zip(cv.split(X, y), range(5)):
#     rf.fit(X.iloc[train], y.iloc[train])
#     _, _, auc_score_train = compute_roc_auc(train)
#     fpr, tpr, auc_score = compute_roc_auc(test)
#     scores.append((auc_score_train, auc_score))
#     fprs.append(fpr)
#     tprs.append(tpr)
#
# plot_roc_curve(fprs, tprs);
# pd.DataFrame(scores, columns=['AUC Train', 'AUC Test'])

# %% [markdown]
# ## Running the RanFor Model with n-grams

# %%
X = reviews.drop(columns='rating')
y = reviews['rating']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train = pd.DataFrame(X_train, columns=X.columns)
X_test  = pd.DataFrame(X_test, columns=X.columns)
y_train = pd.DataFrame(y_train, columns =['rating'])
y_test  = pd.DataFrame(y_test, columns =['rating'])

# %%
X_train
#y_train
# Out:
#        feel  medication  anxiety  doctor  medicine  weight  better  sleep  \
# 35889     0           0        0       0         0       0       0      0
# 82468     0           0        1       0         0       0       1      0
# 72444     1           1        1       1         0       0       0      0
# 75605     0           0        0       0         2       0       0      1
# 10671     0           4        0       0         1       0       0      0
# ...     ...         ...      ...     ...       ...     ...     ...    ...
# 6265      0           0        0       0         2       2       0      1
# 54886     0           0        0       0         0       1       0      0
# 76820     0           0        0       0         0       0       0      0
# 860       1           0        1       2         0       0       1      0
# 15795     0           0        0       0         0       0       0      0
#
#        work  really  ...  taken  able  experience  make  say  finally  blood  \
# 35889     0       0  ...      0     0           0     0    0        0      0
# 82468     0       0  ...      0     0           0     0    0        0      0
# 72444     0       0  ...      0     0           0     0    0        0      0
# 75605     0       0  ...      0     0           0     0    0        1      0
# 10671     1       0  ...      0     0           0     0    0        0      0
# ...     ...     ...  ...    ...   ...         ...   ...  ...      ...    ...
# 6265      1       0  ...      0     0           0     0    0        0      0
# 54886     0       0  ...      0     0           0     1    0        0      0
# 76820     0       1  ...      0     0           0     0    0        0      0
# 860       0       1  ...      0     0           0     0    0        0      0
# 15795     0       0  ...      0     0           0     0    0        0      0
#
#        stop  gone  recommend
# 35889     0     0          0
# 82468     0     0          0
# 72444     0     0          0
# 75605     1     0          0
# 10671     0     0          0
# ...     ...   ...        ...
# 6265      0     0          0
# 54886     0     0          1
# 76820     0     0          0
# 860       1     0          0
# 15795     0     0          0
#
# [73477 rows x 59 columns]

# %%
y_test.value_counts()
# Out:
# rating
# 10.0      6554
# 9.0       3368
# 8.0       2276
# 1.0       2019
# 7.0       1032
# 5.0        768
# 6.0        689
# 2.0        610
# 3.0        589
# 4.0        465
# dtype: int64

# %%
from sklearn.naive_bayes import CategoricalNB
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train['rating'])
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Making predictions with RF

# %%
y_train_pred = rf.predict(X_train)
y_test_pred  = rf.predict(X_test)

# %%
train_err = y_train_pred - y_train['rating'].values
test_err = y_test_pred - y_test['rating'].values
train_err = np.mean(np.sqrt(train_err**2))/y_train['rating'].values.mean()
test_err = np.mean(np.sqrt(test_err**2))/y_test['rating'].values.mean()
print('train err: %.3f test err: %.3f' % (train_err,test_err))
# Out:
# train err: 0.176 test err: 0.340

# %% [markdown]
# ### Model performance

# %% [markdown]
# #### Tuning the hyper paramters with gridsearch

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [5, 8, 10],
    'bootstrap': [True, False],
    'min_samples_leaf' : [1, 2],
    'max_features': ['sqrt', 'log2']
    #'max_samples' : ['None', 0.5]
    }
clf = RandomForestRegressor(random_state=42)

# %%
grid_search = GridSearchCV(clf, param_grid, cv=5,return_train_score=True,n_jobs=-1,)

# %%
# grid_search.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:880: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_depth': [5, 8, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'n_estimators': [50, 100]},
#              return_train_score=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:593: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'n_estimators': 100}

# %%
## Rerunning model

# %%
clf = RandomForestRegressor(max_depth=10,max_features="sqrt",n_estimators=100,min_samples_leaf=2,random_state=0,bootstrap=True)
clf.fit(X_train, y_train)
print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))
# Out:
# /tmp/ipykernel_527542/2881827866.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train, y_train)
# 0.07524694555197009
# 0.059664696087869507

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.318727      0.024232         0.040641        0.002709
# 1        2.489682      0.076136         0.075407        0.006250
# 2        1.218925      0.074645         0.043104        0.005383
# 3        2.381634      0.048163         0.073985        0.005870
# 4        1.042979      0.107467         0.042962        0.001807
# 5        1.899275      0.035797         0.077017        0.003017
# 6        0.943493      0.028522         0.042137        0.003307
# 7        1.882684      0.026114         0.079484        0.003437
# 8        1.804532      0.019689         0.068492        0.001617
# 9        3.614677      0.093735         0.129722        0.003141
# 10       1.805870      0.080592         0.069544        0.000875
# 11       3.718380      0.079675         0.132170        0.002342
# 12       1.647614      0.082690         0.083551        0.014378
# 13       3.282035      0.186426         0.129291        0.013736
# 14       1.529581      0.041657         0.068471        0.002778
# 15       3.199375      0.139038         0.133465        0.009642
# 16       2.353918      0.087888         0.086814        0.006684
# 17       4.678807      0.037900         0.167006        0.008879
# 18       2.464543      0.113018         0.086997        0.003454
# 19       5.126887      0.168061         0.173203        0.022885
# 20       2.028810      0.075088         0.100990        0.005342
# 21       4.039309      0.140606         0.226997        0.068874
# 22       2.000864      0.080373         0.088579        0.004333
# 23       3.849056      0.178283         0.170588        0.007868
# 24       1.447658      0.040047         0.044358        0.002883
# 25       2.790493      0.064958         0.079895        0.001823
# 26       1.419126      0.034634         0.044339        0.002532
# 27       2.819765      0.072532         0.081446        0.000513
# 28       1.126010      0.022088         0.044566        0.002897
# 29       2.188830      0.049141         0.080167        0.002113
# 30       1.118296      0.029000         0.044344        0.001919
# 31       2.214326      0.035484         0.080127        0.002990
# 32       2.311479      0.061138         0.070824        0.001373
# 33       4.598052      0.132443         0.131578        0.002415
# 34       2.324324      0.037541         0.072277        0.002186
# 35       4.579938      0.117757         0.130174        0.006185
# 36       1.796928      0.067845         0.071766        0.002027
# 37       3.516119      0.083467         0.132502        0.004450
# 38       1.760151      0.044207         0.070533        0.001135
# 39       3.544737      0.091096         0.130106        0.001540
# 40       3.005066      0.105121         0.085490        0.005981
# 41       5.904086      0.138647         0.169965        0.005006
# 42       2.932480      0.064920         0.084415        0.008609
# 43       5.856726      0.171579         0.163146        0.006591
# 44       2.332165      0.017359         0.084697        0.003570
# 45       4.527699      0.126950         0.164170        0.012449
# 46       2.286916      0.051724         0.090122        0.003239
# 47       4.597284      0.689122         0.143344        0.039053
#
#    param_bootstrap param_max_depth param_max_features param_min_samples_leaf  \
# 0             True               5               sqrt                      1
# 1             True               5               sqrt                      1
# 2             True               5               sqrt                      2
# 3             True               5               sqrt                      2
# 4             True               5               log2                      1
# 5             True               5               log2                      1
# 6             True               5               log2                      2
# 7             True               5               log2                      2
# 8             True               8               sqrt                      1
# 9             True               8               sqrt                      1
# 10            True               8               sqrt                      2
# 11            True               8               sqrt                      2
# 12            True               8               log2                      1
# 13            True               8               log2                      1
# 14            True               8               log2                      2
# 15            True               8               log2                      2
# 16            True              10               sqrt                      1
# 17            True              10               sqrt                      1
# 18            True              10               sqrt                      2
# 19            True              10               sqrt                      2
# 20            True              10               log2                      1
# 21            True              10               log2                      1
# 22            True              10               log2                      2
# 23            True              10               log2                      2
# 24           False               5               sqrt                      1
# 25           False               5               sqrt                      1
# 26           False               5               sqrt                      2
# 27           False               5               sqrt                      2
# 28           False               5               log2                      1
# 29           False               5               log2                      1
# 30           False               5               log2                      2
# 31           False               5               log2                      2
# 32           False               8               sqrt                      1
# 33           False               8               sqrt                      1
# 34           False               8               sqrt                      2
# 35           False               8               sqrt                      2
# 36           False               8               log2                      1
# 37           False               8               log2                      1
# 38           False               8               log2                      2
# 39           False               8               log2                      2
# 40           False              10               sqrt                      1
# 41           False              10               sqrt                      1
# 42           False              10               sqrt                      2
# 43           False              10               sqrt                      2
# 44           False              10               log2                      1
# 45           False              10               log2                      1
# 46           False              10               log2                      2
# 47           False              10               log2                      2
#
#    param_n_estimators                                             params  ...  \
# 0                  50  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 1                 100  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 2                  50  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 3                 100  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 4                  50  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 5                 100  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 6                  50  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 7                 100  {'bootstrap': True, 'max_depth': 5, 'max_featu...  ...
# 8                  50  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 9                 100  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 10                 50  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 11                100  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 12                 50  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 13                100  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 14                 50  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 15                100  {'bootstrap': True, 'max_depth': 8, 'max_featu...  ...
# 16                 50  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 17                100  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 18                 50  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 19                100  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 20                 50  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 21                100  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 22                 50  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 23                100  {'bootstrap': True, 'max_depth': 10, 'max_feat...  ...
# 24                 50  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 25                100  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 26                 50  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 27                100  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 28                 50  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 29                100  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 30                 50  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 31                100  {'bootstrap': False, 'max_depth': 5, 'max_feat...  ...
# 32                 50  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 33                100  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 34                 50  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 35                100  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 36                 50  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 37                100  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 38                 50  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 39                100  {'bootstrap': False, 'max_depth': 8, 'max_feat...  ...
# 40                 50  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
# 41                100  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
# 42                 50  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
# 43                100  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
# 44                 50  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
# 45                100  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
# 46                 50  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
# 47                100  {'bootstrap': False, 'max_depth': 10, 'max_fea...  ...
#
#     mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0          0.036519        0.001515               34            0.039899
# 1          0.036477        0.001233               36            0.040037
# 2          0.036564        0.001567               33            0.039834
# 3          0.036496        0.001241               35            0.039918
# 4          0.033132        0.001004               44            0.036515
# 5          0.033048        0.000949               46            0.036259
# 6          0.033259        0.000955               41            0.036573
# 7          0.033180        0.000921               42            0.036148
# 8          0.050221        0.002193               24            0.062721
# 9          0.050780        0.001922               20            0.062945
# 10         0.050522        0.002018               23            0.061470
# 11         0.051023        0.001872               17            0.061894
# 12         0.047654        0.001619               28            0.058470
# 13         0.047504        0.001560               31            0.058134
# 14         0.047991        0.001694               25            0.057508
# 15         0.047772        0.001615               26            0.057171
# 16         0.057609        0.002423                8            0.081837
# 17         0.058589        0.002253                3            0.082193
# 18         0.057973        0.002287                5            0.077622
# 19         0.058935        0.002153                1            0.078575
# 20         0.055365        0.001678               15            0.076181
# 21         0.055368        0.001693               14            0.076133
# 22         0.055427        0.001673               13            0.072044
# 23         0.055555        0.001666               12            0.072111
# 24         0.036278        0.001371               40            0.039860
# 25         0.036282        0.001316               39            0.039815
# 26         0.036301        0.001318               38            0.039822
# 27         0.036312        0.001300               37            0.039739
# 28         0.033089        0.001022               45            0.036195
# 29         0.032988        0.000942               48            0.036129
# 30         0.033140        0.001003               43            0.036081
# 31         0.033039        0.000917               47            0.035941
# 32         0.050639        0.002009               22            0.063771
# 33         0.050926        0.001863               19            0.064098
# 34         0.050652        0.001871               21            0.062708
# 35         0.050961        0.001866               18            0.063153
# 36         0.047617        0.001765               30            0.059326
# 37         0.047652        0.001658               29            0.059239
# 38         0.047439        0.001428               32            0.058090
# 39         0.047663        0.001436               27            0.057917
# 40         0.057735        0.002063                7            0.084643
# 41         0.058566        0.002047                4            0.085138
# 42         0.057846        0.002277                6            0.080878
# 43         0.058743        0.002171                2            0.081605
# 44         0.055343        0.001592               16            0.078491
# 45         0.055569        0.001681               11            0.078399
# 46         0.055704        0.001571               10            0.075263
# 47         0.055801        0.001509                9            0.074990
#
#     split1_train_score  split2_train_score  split3_train_score  \
# 0             0.039879            0.039835            0.039019
# 1             0.039919            0.039861            0.038909
# 2             0.039794            0.039736            0.039164
# 3             0.039810            0.039797            0.038840
# 4             0.036272            0.036180            0.035380
# 5             0.036199            0.036057            0.035301
# 6             0.036067            0.036216            0.035261
# 7             0.036023            0.036008            0.035143
# 8             0.063102            0.062804            0.061695
# 9             0.063289            0.063149            0.061924
# 10            0.061511            0.061261            0.060404
# 11            0.061725            0.061721            0.060793
# 12            0.058466            0.058370            0.057182
# 13            0.058437            0.058224            0.057259
# 14            0.057181            0.057485            0.055962
# 15            0.057060            0.057052            0.055979
# 16            0.082064            0.081240            0.079603
# 17            0.082391            0.082125            0.080760
# 18            0.077765            0.077713            0.076376
# 19            0.078406            0.078315            0.077179
# 20            0.076346            0.075789            0.074807
# 21            0.076464            0.075913            0.074837
# 22            0.072496            0.072051            0.070797
# 23            0.072567            0.072163            0.070873
# 24            0.040034            0.040046            0.038968
# 25            0.039861            0.039998            0.039031
# 26            0.039811            0.039936            0.038720
# 27            0.039726            0.039897            0.038842
# 28            0.035934            0.036475            0.035463
# 29            0.035938            0.036136            0.035359
# 30            0.035842            0.036302            0.035307
# 31            0.035882            0.035968            0.035200
# 32            0.064500            0.063948            0.063162
# 33            0.064745            0.064418            0.063410
# 34            0.063057            0.062770            0.061850
# 35            0.063376            0.063096            0.062019
# 36            0.059765            0.059409            0.058216
# 37            0.059755            0.059449            0.058378
# 38            0.058247            0.058036            0.057108
# 39            0.058395            0.058048            0.057262
# 40            0.084885            0.085262            0.083769
# 41            0.085779            0.085818            0.084305
# 42            0.081894            0.081023            0.080021
# 43            0.082470            0.081822            0.080768
# 44            0.078905            0.079360            0.077834
# 45            0.079401            0.079302            0.078189
# 46            0.075327            0.075173            0.074096
# 47            0.075722            0.075398            0.074344
#
#     split4_train_score  mean_train_score  std_train_score
# 0             0.038638          0.039454         0.000525
# 1             0.038633          0.039472         0.000582
# 2             0.038643          0.039434         0.000464
# 3             0.038620          0.039397         0.000550
# 4             0.034931          0.035855         0.000599
# 5             0.034972          0.035758         0.000522
# 6             0.034753          0.035774         0.000667
# 7             0.034827          0.035630         0.000538
# 8             0.061552          0.062375         0.000628
# 9             0.061780          0.062617         0.000636
# 10            0.060350          0.060999         0.000516
# 11            0.060674          0.061361         0.000518
# 12            0.056969          0.057891         0.000671
# 13            0.057186          0.057848         0.000521
# 14            0.055617          0.056751         0.000800
# 15            0.055797          0.056612         0.000595
# 16            0.080239          0.080997         0.000940
# 17            0.081037          0.081701         0.000667
# 18            0.076539          0.077203         0.000613
# 19            0.077189          0.077933         0.000617
# 20            0.075250          0.075675         0.000575
# 21            0.075229          0.075715         0.000597
# 22            0.070894          0.071656         0.000683
# 23            0.071115          0.071766         0.000654
# 24            0.038719          0.039525         0.000566
# 25            0.038744          0.039490         0.000504
# 26            0.038549          0.039367         0.000603
# 27            0.038583          0.039357         0.000536
# 28            0.035251          0.035864         0.000452
# 29            0.035242          0.035761         0.000384
# 30            0.035154          0.035737         0.000441
# 31            0.035161          0.035630         0.000368
# 32            0.063312          0.063739         0.000477
# 33            0.063260          0.063986         0.000572
# 34            0.061749          0.062427         0.000527
# 35            0.061706          0.062670         0.000673
# 36            0.058315          0.059006         0.000623
# 37            0.058313          0.059027         0.000580
# 38            0.056795          0.057655         0.000587
# 39            0.056990          0.057722         0.000519
# 40            0.083631          0.084438         0.000636
# 41            0.084196          0.085047         0.000695
# 42            0.080107          0.080785         0.000684
# 43            0.080590          0.081451         0.000694
# 44            0.077984          0.078515         0.000568
# 45            0.078422          0.078743         0.000505
# 46            0.074176          0.074807         0.000551
# 47            0.074357          0.074962         0.000551
#
# [48 rows x 25 columns]

# %%
from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(random_state=42, max_features='sqrt', 
                             min_samples_leaf=1, min_samples_split=2, n_estimators=100)
cross_val_scores = cross_val_score(clf, X_train, y_train, cv=10)
print(np.mean(cross_val_scores))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       1 from sklearn.model_selection import cross_val_score
# ----> 2 clf = RandomForestClassifier(random_state=42, max_features='sqrt',
#       3                              min_samples_leaf=1, min_samples_split=2, n_estimators=100)
#       4 cross_val_scores = cross_val_score(clf, X_train, y_train, cv=10)
#       5 print(np.mean(cross_val_scores))
#
# NameError: name 'RandomForestClassifier' is not defined

# %% [markdown]
# #### Running the Naive Bayes model

# %%
y_train
X_train

# %%
nb = CategoricalNB()
nb.fit(X_train, y_train['rating'])

# %% [markdown]
# (Not) Making predictions with NB

# %%
y_train_pred_nb = nb.predict(X_train)
y_test_pred_nb  = nb.predict(X_test)

# %% [markdown]
# Model performance

# %%
model_performance_class(y_train, y_train_pred_nb, y_test, y_test_pred_nb)

# %% [markdown]
# ### SVC instead of NB

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(random_state=42, tol=1e-2, max_iter=5000)

# %%
svm.fit(X_train, y_train)

# %%
y_train_pred_svm = svm.predict(X_train)
y_test_pred_svm  = svm.predict(X_test)

# %%
model_performance_class(y_train, y_train_pred_svm, y_test, y_test_pred_svm)

# %%
# terrible

# %% [markdown]
# ## TF-IDF (Term-Frequency Inverse Document-Frequency)

# %% [markdown]
# ### Dataset prep: re-cleaning reviews

# %%
# Using Rafa's nice function from now on

def clean_review(x):
    x = str(x).lower().replace("\\","").replace("_"," ")
    x = re.sub(r'\W+',' ',x) # Replace everything non-alpahnumeric by ' '
    x = re.sub(r'\s+',' ',x) # Replace one or more whitespaces by  ' '
    x = re.sub(r'\d+',' ',x) # Replace one or more digits by  ' '
    x = re.sub(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)'," ", x) # Replace e-mails by ''
    # Replace urls by ''
    x = re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', ' ' , x) 
    # Replace html tags by ''
    x = BeautifulSoup(x, 'html.parser').get_text().strip()
    x = x.replace(' br ',' ')

    return x

# %%
reviews_cleaned = df.copy()

# %%
reviews_cleaned = reviews_cleaned[['review','rating']]

# %%
reviews_cleaned.head()

# %%
reviews_cleaned['review'] = reviews_cleaned['review'].apply(lambda x: clean_review(x))

# %%
reviews_cleaned.head()

# %% [markdown]
# ### >>> Running the TF-IDF model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tidf = TfidfVectorizer(max_features = 20000, ngram_range = (1,2), analyzer = 'word',
                       stop_words = stop_words )

# %%
X_TF = tidf.fit_transform(reviews_cleaned['review'])
y_TF = reviews_cleaned['rating']

# %%
tidf.get_feature_names()

# %%
len(tidf.get_feature_names())

# %%
X_TF[:2,:5]

# %% [markdown]
# #### Train test split

# %%
X_TF_train, X_TF_test, y_TF_train, y_TF_test = train_test_split(X_TF, y_TF, test_size=0.20, random_state=42)

# %%
type(X_TF_train)

# %% [markdown]
# #### Generating the model

# %%
rf1 = RandomForestClassifier(max_depth=200, n_estimators=50)

y_TF_train = y_TF_train.astype('int')
y_TF_test  = y_TF_test.astype('int')

rf1.fit(X_TF_train, y_TF_train)

y_TF_train_pred_rf = rf1.predict(X_TF_train)
y_TF_test_pred_rf  = rf1.predict(X_TF_test)

# %% [markdown]
# #### Model performance

# %%
model_performance_class(y_TF_train, y_TF_train_pred_rf, y_TF_test, y_TF_test_pred_rf)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix

performance_df = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_TF_train, y_TF_train_pred_rf),
                                         precision_score(y_TF_train, y_TF_train_pred_rf),
                                         recall_score(y_TF_train, y_TF_train_pred_rf)],
                               'Test': [accuracy_score(y_TF_test, y_TF_test_pred_rf),
                                        precision_score(y_TF_test, y_TF_test_pred_rf),
                                        recall_score(y_TF_test, y_TF_test_pred_rf)]})

display(performance_df)

print("Confusion matrix for the train set")
print(confusion_matrix(y_TF_train,y_TF_train_pred_rf).T)
plot_confusion_matrix(rf1, X_TF_train, y_TF_train, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_TF_test,y_TF_test_pred_rf).T)
plot_confusion_matrix(rf1, X_TF_test,y_TF_test, values_format = 'd')
plt.show()

# %%
ax = sns.barplot(x="Error_metric", y="Test", data=performance_df)

# %% [markdown]
# ## Modeling (DOWNSAMPLE)

# %% [markdown]
# ### Cross-validation?

# %% [markdown]
# from sklearn.model_selection import StratifiedKFold
#
# cv = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
# results = pd.DataFrame(columns=['training_score', 'test_score'])
# fprs, tprs, scores = [], [], []

# %% [markdown]
# for (train, test), i in zip(cv.split(X, y), range(5)):
#     rf.fit(X.iloc[train], y.iloc[train])
#     _, _, auc_score_train = compute_roc_auc(train)
#     fpr, tpr, auc_score = compute_roc_auc(test)
#     scores.append((auc_score_train, auc_score))
#     fprs.append(fpr)
#     tprs.append(tpr)
#
# plot_roc_curve(fprs, tprs);
# pd.DataFrame(scores, columns=['AUC Train', 'AUC Test'])

# %% [markdown]
# ## >>> Running the RanFor Model with BOW

# %%
X2 = reviews2.drop(columns='rating')
y2 = reviews2['rating']
X2

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.20, random_state=42)

X_train2 = pd.DataFrame(X_train2, columns=X2.columns)
X_test2  = pd.DataFrame(X_test2, columns=X2.columns)

y_train2 = pd.DataFrame(y_train2, columns =['rating'])
y_test2  = pd.DataFrame(y_test2, columns =['rating'])

# %%
X_train2
#y_train2

# %%
y_test2.value_counts()

# %%
rf2 = RandomForestClassifier()

rf2.fit(X_train2, y_train2['rating'])

# %% [markdown]
# ### Making predictions with RF

# %%
y_train_pred_rf2 = rf2.predict(X_train2)
y_test_pred_rf2  = rf2.predict(X_test2)

# %%
def model_performance_class(y_train, y_pred_train, y_test, y_pred_test):

    from sklearn.metrics import cohen_kappa_score, classification_report 


    print("Results obtained for the TRAIN SET")
    print("==================================")
    print("The Cohen's Kappa is: {:.2f}".format(cohen_kappa_score(y_train, y_pred_train)))
    print(classification_report(y_train, y_pred_train))
    print("==================================")
    print("Results obtained for the TEST SET")
    print("The Cohen's Kappa is: {:.2f}".format(cohen_kappa_score(y_test, y_pred_test)))
    print(classification_report(y_test, y_pred_test))

# %% [markdown]
# ### Model performance

# %%
model_performance_class(y_train2, y_train_pred_rf2, y_test2, y_test_pred_rf2)

# %%
# After balancing, overall score is lower, precision overall lower
# test + train set recall better for lower rating drugs [0] (less false positives)
# But more false negatives - good drugs [1] are predicted as bad more often

# %% [markdown]
# #### Tuning the hyper paramters with gridsearch

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [5, 8, 10],
    'bootstrap': [True, False],
    'min_samples_leaf' : [1, 2],
    'max_features': ['sqrt', 'log2']
    #'max_samples' : ['None', 0.5]
    }
clf = RandomForestClassifier(random_state=42)

# %%
grid_search = GridSearchCV(clf, param_grid, cv=5,return_train_score=True,n_jobs=-1,)

# %% [markdown]
# grid_search.fit(X_train2,y_train2)

# %%
grid_search.best_params_

# %%
clf = RandomForestClassifier(max_depth=10,max_features="sqrt",n_estimators=500, min_samples_leaf =1, random_state=42)
clf.fit(X_train2, y_train2)
print(clf.score(X_train2, y_train2))
print(clf.score(X_test2, y_test2))

# %%
# What does that mean?

# %%
pd.DataFrame(grid_search.cv_results_)

# %%
clf = RandomForestClassifier(random_state=42, max_features='sqrt', 
                             min_samples_leaf=1, min_samples_split=2, n_estimators=100)
cross_val_scores = cross_val_score(clf, X_train2, y_train2, cv=10)
print(np.mean(cross_val_scores))

# %% [markdown]
# ## TF_IDF DOWNSAMPLE

# %% [markdown]
# ### >>> With uni + bigrams

# %%
df_down

# %%
tidf = TfidfVectorizer(max_features = 20000, ngram_range = (1,2), analyzer = 'word',
                       stop_words = stop_words, min_df=2 )

# %%
X_TF2 = tidf.fit_transform(df_down['review'])
y_TF2 = df_down['rating']

# %%
y_TF2

# %%
tidf.get_feature_names()

# %%
len(tidf.get_feature_names())

# %%
X_TF2[:2,:5]

# %% [markdown]
# #### Train test split

# %%
X_TF_train2, X_TF_test2, y_TF_train2, y_TF_test2 = train_test_split(X_TF2, y_TF2, test_size=0.20, random_state=42)

# %%
type(X_TF_train2)

# %% [markdown]
# #### Generating the model

# %%
rf3 = RandomForestClassifier(max_depth=200, n_estimators=50)

y_TF_train2 = y_TF_train2.astype('int')
y_TF_test2  = y_TF_test2.astype('int')

rf3.fit(X_TF_train2, y_TF_train2)

y_TF_train_pred_rf2 = rf3.predict(X_TF_train2)
y_TF_test_pred_rf2  = rf3.predict(X_TF_test2)

# %% [markdown]
# #### Model performance

# %%
model_performance_class(y_TF_train2, y_TF_train_pred_rf2, y_TF_test2, y_TF_test_pred_rf2)

# %%
# best results obtained with uni- AND bi-grams, max_depth 200

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix

performance_df_best = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_TF_train2, y_TF_train_pred_rf2),
                                         precision_score(y_TF_train2, y_TF_train_pred_rf2),
                                         recall_score(y_TF_train2, y_TF_train_pred_rf2)],
                               'Test': [accuracy_score(y_TF_test2, y_TF_test_pred_rf2),
                                        precision_score(y_TF_test2, y_TF_test_pred_rf2),
                                        recall_score(y_TF_test2, y_TF_test_pred_rf2)]})

display(performance_df_best)

print("Confusion matrix for the train set")
print(confusion_matrix(y_TF_train2,y_TF_train_pred_rf2).T)
plot_confusion_matrix(rf3, X_TF_train2, y_TF_train2, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_TF_test2,y_TF_test_pred_rf2).T)
plot_confusion_matrix(rf3, X_TF_test2,y_TF_test2, values_format = 'd')
plt.show()

# %% [markdown]
# ### >>> With bigrams only

# %%
tidf = TfidfVectorizer(max_features = 20000, ngram_range = (2,2), analyzer = 'word',
                       stop_words = stop_words, min_df=2 )

# %%
X_TF_down_bi = tidf.fit_transform(df_down['review'])
y_TF_down_bi = df_down['rating']

# %% [markdown]
# #### Train test split

# %%
X_TF_down_bi_train, X_TF_down_bi_test, y_TF_down_bi_train, y_TF_down_bi_test = train_test_split(X_TF_down_bi, y_TF_down_bi, test_size=0.20, random_state=42)

# %%
type(X_TF_down_bi_train)

# %% [markdown]
# #### Generating the model

# %%
rf4 = RandomForestClassifier(max_depth=200, n_estimators=50)

y_TF_down_bi_train = y_TF_down_bi_train.astype('int')
y_TF_down_bi_test  = y_TF_down_bi_test.astype('int')

rf4.fit(X_TF_down_bi_train, y_TF_down_bi_train)

y_TF_down_bi_train_pred_rf = rf4.predict(X_TF_down_bi_train)
y_TF_down_bi_test_pred_rf  = rf4.predict(X_TF_down_bi_test)

# %% [markdown]
# #### Model performance

# %%
model_performance_class(y_TF_down_bi_train, y_TF_down_bi_train_pred_rf, y_TF_down_bi_test, 
                        y_TF_down_bi_test_pred_rf)

# %% [markdown]
# #### Tuning the hyper paramters with gridsearch

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [150, 200],
    'bootstrap': [True, False],
    'min_samples_leaf' : [1, 2],
    'max_features': ['sqrt', 'log2']
    #'max_samples' : ['None', 0.5]
    }
clf = RandomForestClassifier(random_state=42)

# %%
grid_search = GridSearchCV(clf, param_grid, cv=5,return_train_score=True,n_jobs=-1,)

# %%
grid_search.fit(X_TF_train2,y_TF_train2)

# %%
grid_search.best_params_

# %%
#pd.DataFrame(grid_search.cv_results_)

# %%
cross_val_scores = cross_val_score(clf, X_train2, y_train2, cv=10)
print(np.mean(cross_val_scores))

# %%
metrics.RocCurveDisplay

# %%
metrics.RocCurveDisplay.from_estimator

# %%
# 1 - BOW, down
disp = plot_roc_curve(rf2, X_test2, y_test2, name="BOW, balanced")
plt.gcf().set_size_inches(12,6)
#2 - TF-IDF down bi grams
plot_roc_curve(rf4, X_TF_down_bi_test, y_TF_down_bi_test, name="TF-IDF, balanced, bigrams", ax=disp.ax_);

#3 - TF-IDF down uni/bi grams
plot_roc_curve(rf3, X_TF_test2, y_TF_test2, name="TF-IDF, balanced, uni+bigrams", ax=disp.ax_);

#4 - TF-IDF full uni/bi grams
plot_roc_curve(rf1, X_TF_test, y_TF_test, name="TF-IDF, imbalanced, uni+bigrams", ax=disp.ax_);

# %%
# Plot recall (chose green option as recall for cat 1 is better)

# %%
performance_df1 = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               #'Train': [accuracy_score(y_TF_train, y_TF_train_pred_rf),
                                #         precision_score(y_TF_train, y_TF_train_pred_rf),
                                 #        recall_score(y_TF_train, y_TF_train_pred_rf)],
                               'Test': [accuracy_score(y_TF_test, y_TF_test_pred_rf),
                                        precision_score(y_TF_test, y_TF_test_pred_rf),
                                        recall_score(y_TF_test, y_TF_test_pred_rf)]})
performance_df_best1 = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               #'Train': [accuracy_score(y_TF_train2, y_TF_train_pred_rf2),
                               #          precision_score(y_TF_train2, y_TF_train_pred_rf2),
                                #         recall_score(y_TF_train2, y_TF_train_pred_rf2)],
                               'Test': [accuracy_score(y_TF_test2, y_TF_test_pred_rf2),
                                        precision_score(y_TF_test2, y_TF_test_pred_rf2),
                                        recall_score(y_TF_test2, y_TF_test_pred_rf2)]})

# %%
performance_df1

# %%
performance_df_best1
